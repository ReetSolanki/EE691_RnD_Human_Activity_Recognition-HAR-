# %%
# Install dependencies
# !pip install ultralytics opencv-python numpy ffmpeg-python
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.107-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.107-py3-none-any.whl (974 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.5/974.5 kB 17.3 MB/s eta 0:00:00
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ffmpeg-python, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed ffmpeg-python-0.2.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.107 ultralytics-thop-2.0.14

# %%
import cv2
import numpy as np
import ffmpeg
from ultralytics import YOLO
from google.colab import files

# Define input video (must be manually uploaded to Colab first)
input_video = "all.mp4"  # Change this to your uploaded file
output_video = "action_output.mp4"

# Load YOLOv8 Pose Model
model = YOLO("yolov8n-pose.pt")

# Open the input video
cap = cv2.VideoCapture(input_video)
if not cap.isOpened():
    print("❌ ERROR: Cannot open video.")
    exit()

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS)) or 20
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video, fourcc, fps, (width, height))

# Ground level for detecting jumps (initialize dynamically)
ground_level = None
jump_threshold = 20  # Pixels above ground level to detect jump
jump_status = "Standing"

# Function to classify Jumping, Standing, or Sitting
def detect_action(keypoints):
    global ground_level, jump_status

    # Keypoints for lower body
    left_hip, right_hip = keypoints[11], keypoints[12]
    left_knee, right_knee = keypoints[13], keypoints[14]
    left_ankle, right_ankle = keypoints[15], keypoints[16]

    # Convert to NumPy arrays
    left_hip, right_hip = np.array(left_hip), np.array(right_hip)
    left_knee, right_knee = np.array(left_knee), np.array(right_knee)
    left_ankle, right_ankle = np.array(left_ankle), np.array(right_ankle)

    # Compute average positions
    avg_hip_y = (left_hip[1] + right_hip[1]) / 2
    avg_knee_y = (left_knee[1] + right_knee[1]) / 2
    avg_ankle_y = (left_ankle[1] + right_ankle[1]) / 2

    # Initialize ground level on first frame
    if ground_level is None:
        ground_level = avg_ankle_y

    # Check if the subject is Jumping
    if avg_ankle_y < ground_level - jump_threshold:
        jump_status = "Jumping"
    # Check for Sitting: hips close to knees, and ankles are not too high
    #elif abs(avg_hip_y - avg_knee_y) < 20 and avg_ankle_y > avg_knee_y:
    elif abs(avg_hip_y - avg_knee_y) < 70:
        jump_status = "Sitting"
    else:
        jump_status = "Standing"

    return jump_status

# Process frames
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # End of video

    # Run YOLO Pose Estimation
    results = model(frame)

    # Draw keypoints and classify action
    for r in results:
        for kp in r.keypoints.xy:
            keypoints = kp.cpu().numpy()
            action = detect_action(keypoints)

            # Get bounding box (person detection)
            x1, y1, x2, y2 = map(int, r.boxes.xyxy[0])

            # Define color based on action
            if action == "Jumping":
                color = (0, 0, 255)  # Red
            elif action == "Sitting":
                color = (255, 0, 0)  # Blue
            else:
                color = (0, 255, 0)  # Green

            # Draw bounding box & label
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, action, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

            # Draw keypoints
            for (x, y) in keypoints:
                cv2.circle(frame, (int(x), int(y)), 3, (0, 255, 255), -1)

    out.write(frame)

# Cleanup
cap.release()
out.release()
print("✅ Processing complete. Video saved as", output_video)

# Compress video using FFmpeg
compressed_video = "final_action_output.mp4"
# !ffmpeg -i action_output.mp4 -c:v libx264 -preset slow -crf 23 -pix_fmt yuv420p {compressed_video}
# Out:
# 0: 640x384 1 person, 310.1ms
# Speed: 14.5ms preprocess, 310.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 271.8ms
# Speed: 6.6ms preprocess, 271.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 260.4ms
# Speed: 6.4ms preprocess, 260.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 277.1ms
# Speed: 10.3ms preprocess, 277.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 273.7ms
# Speed: 8.2ms preprocess, 273.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 303.9ms
# Speed: 4.1ms preprocess, 303.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 294.5ms
# Speed: 7.6ms preprocess, 294.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 193.9ms
# Speed: 6.7ms preprocess, 193.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 201.2ms
# Speed: 6.6ms preprocess, 201.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 192.8ms
# Speed: 5.1ms preprocess, 192.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 188.2ms
# Speed: 6.5ms preprocess, 188.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 194.6ms
# Speed: 7.7ms preprocess, 194.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 192.8ms
# Speed: 6.4ms preprocess, 192.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 181.5ms
# Speed: 6.6ms preprocess, 181.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.8ms
# Speed: 3.6ms preprocess, 173.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.9ms
# Speed: 5.5ms preprocess, 171.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 181.8ms
# Speed: 5.4ms preprocess, 181.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.4ms
# Speed: 5.8ms preprocess, 170.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 178.1ms
# Speed: 5.7ms preprocess, 178.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.6ms
# Speed: 5.7ms preprocess, 170.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.2ms
# Speed: 3.0ms preprocess, 168.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 187.8ms
# Speed: 5.1ms preprocess, 187.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.8ms
# Speed: 6.1ms preprocess, 172.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.3ms
# Speed: 5.6ms preprocess, 165.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.5ms
# Speed: 4.0ms preprocess, 170.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.0ms
# Speed: 6.0ms preprocess, 170.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 180.8ms
# Speed: 3.3ms preprocess, 180.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.6ms
# Speed: 3.6ms preprocess, 161.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.8ms
# Speed: 3.7ms preprocess, 167.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 174.5ms
# Speed: 7.5ms preprocess, 174.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.2ms
# Speed: 6.0ms preprocess, 170.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.2ms
# Speed: 4.8ms preprocess, 170.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 179.9ms
# Speed: 5.6ms preprocess, 179.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 174.9ms
# Speed: 5.7ms preprocess, 174.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.7ms
# Speed: 5.6ms preprocess, 169.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.1ms
# Speed: 5.5ms preprocess, 170.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.4ms
# Speed: 5.6ms preprocess, 173.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 187.0ms
# Speed: 5.9ms preprocess, 187.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.0ms
# Speed: 5.6ms preprocess, 175.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.3ms
# Speed: 6.6ms preprocess, 175.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 184.6ms
# Speed: 5.9ms preprocess, 184.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 194.5ms
# Speed: 6.3ms preprocess, 194.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 203.3ms
# Speed: 6.9ms preprocess, 203.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 187.0ms
# Speed: 6.2ms preprocess, 187.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 196.1ms
# Speed: 6.8ms preprocess, 196.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 182.4ms
# Speed: 6.8ms preprocess, 182.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 186.6ms
# Speed: 4.5ms preprocess, 186.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 204.2ms
# Speed: 3.8ms preprocess, 204.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 186.4ms
# Speed: 5.4ms preprocess, 186.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 190.5ms
# Speed: 7.2ms preprocess, 190.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 184.6ms
# Speed: 6.8ms preprocess, 184.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 183.7ms
# Speed: 4.3ms preprocess, 183.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 212.7ms
# Speed: 4.0ms preprocess, 212.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 200.0ms
# Speed: 8.0ms preprocess, 200.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 179.4ms
# Speed: 6.4ms preprocess, 179.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 177.7ms
# Speed: 5.4ms preprocess, 177.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 272.8ms
# Speed: 6.3ms preprocess, 272.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 268.4ms
# Speed: 6.3ms preprocess, 268.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 266.0ms
# Speed: 8.0ms preprocess, 266.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 272.0ms
# Speed: 8.5ms preprocess, 272.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 265.8ms
# Speed: 9.1ms preprocess, 265.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 259.0ms
# Speed: 7.7ms preprocess, 259.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 277.5ms
# Speed: 7.0ms preprocess, 277.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 281.0ms
# Speed: 8.9ms preprocess, 281.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 284.9ms
# Speed: 5.7ms preprocess, 284.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 221.7ms
# Speed: 4.8ms preprocess, 221.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.9ms
# Speed: 6.2ms preprocess, 167.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 176.3ms
# Speed: 5.7ms preprocess, 176.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 179.4ms
# Speed: 5.3ms preprocess, 179.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.1ms
# Speed: 7.2ms preprocess, 168.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 186.0ms
# Speed: 6.0ms preprocess, 186.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 186.0ms
# Speed: 6.8ms preprocess, 186.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 192.0ms
# Speed: 6.9ms preprocess, 192.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 197.9ms
# Speed: 4.3ms preprocess, 197.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 186.8ms
# Speed: 6.5ms preprocess, 186.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 189.8ms
# Speed: 6.2ms preprocess, 189.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 191.3ms
# Speed: 5.9ms preprocess, 191.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 191.5ms
# Speed: 6.9ms preprocess, 191.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 203.6ms
# Speed: 7.1ms preprocess, 203.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 178.8ms
# Speed: 4.5ms preprocess, 178.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 174.6ms
# Speed: 7.0ms preprocess, 174.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.9ms
# Speed: 3.7ms preprocess, 167.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.6ms
# Speed: 5.6ms preprocess, 170.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 182.3ms
# Speed: 6.1ms preprocess, 182.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 178.1ms
# Speed: 3.6ms preprocess, 178.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 195.3ms
# Speed: 7.1ms preprocess, 195.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 185.6ms
# Speed: 4.8ms preprocess, 185.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 186.7ms
# Speed: 7.7ms preprocess, 186.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 199.0ms
# Speed: 4.3ms preprocess, 199.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 189.4ms
# Speed: 6.7ms preprocess, 189.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 176.8ms
# Speed: 5.6ms preprocess, 176.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.3ms
# Speed: 5.5ms preprocess, 173.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 180.1ms
# Speed: 6.4ms preprocess, 180.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 182.8ms
# Speed: 5.6ms preprocess, 182.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.3ms
# Speed: 4.3ms preprocess, 165.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 190.1ms
# Speed: 4.3ms preprocess, 190.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 191.2ms
# Speed: 4.2ms preprocess, 191.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 191.7ms
# Speed: 7.3ms preprocess, 191.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 202.1ms
# Speed: 6.6ms preprocess, 202.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 184.9ms
# Speed: 6.6ms preprocess, 184.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.7ms
# Speed: 3.6ms preprocess, 170.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.1ms
# Speed: 5.9ms preprocess, 172.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.4ms
# Speed: 6.7ms preprocess, 175.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 180.2ms
# Speed: 6.2ms preprocess, 180.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.7ms
# Speed: 5.2ms preprocess, 169.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.9ms
# Speed: 5.0ms preprocess, 169.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.7ms
# Speed: 6.4ms preprocess, 173.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.6ms
# Speed: 5.9ms preprocess, 170.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.8ms
# Speed: 5.2ms preprocess, 165.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 174.4ms
# Speed: 7.9ms preprocess, 174.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 188.2ms
# Speed: 7.5ms preprocess, 188.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 194.1ms
# Speed: 6.9ms preprocess, 194.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 195.1ms
# Speed: 7.4ms preprocess, 195.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 207.0ms
# Speed: 7.4ms preprocess, 207.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 266.1ms
# Speed: 6.0ms preprocess, 266.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 295.2ms
# Speed: 7.1ms preprocess, 295.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 294.0ms
# Speed: 9.2ms preprocess, 294.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 290.9ms
# Speed: 4.8ms preprocess, 290.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 259.8ms
# Speed: 6.6ms preprocess, 259.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 258.4ms
# Speed: 3.6ms preprocess, 258.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 271.8ms
# Speed: 6.5ms preprocess, 271.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 288.4ms
# Speed: 6.9ms preprocess, 288.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 298.2ms
# Speed: 10.7ms preprocess, 298.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 285.4ms
# Speed: 8.8ms preprocess, 285.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 203.4ms
# Speed: 8.1ms preprocess, 203.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 187.6ms
# Speed: 6.7ms preprocess, 187.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 190.8ms
# Speed: 7.0ms preprocess, 190.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 190.4ms
# Speed: 4.2ms preprocess, 190.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 192.1ms
# Speed: 6.7ms preprocess, 192.1ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 189.2ms
# Speed: 7.5ms preprocess, 189.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.6ms
# Speed: 7.2ms preprocess, 169.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.3ms
# Speed: 5.9ms preprocess, 172.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.8ms
# Speed: 5.6ms preprocess, 165.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.4ms
# Speed: 4.9ms preprocess, 168.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 199.7ms
# Speed: 4.6ms preprocess, 199.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 197.5ms
# Speed: 7.2ms preprocess, 197.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 194.3ms
# Speed: 6.9ms preprocess, 194.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 189.4ms
# Speed: 5.6ms preprocess, 189.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 197.9ms
# Speed: 6.9ms preprocess, 197.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 200.8ms
# Speed: 9.4ms preprocess, 200.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 190.7ms
# Speed: 3.9ms preprocess, 190.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 188.5ms
# Speed: 3.7ms preprocess, 188.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 186.2ms
# Speed: 4.3ms preprocess, 186.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 206.1ms
# Speed: 4.6ms preprocess, 206.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 194.2ms
# Speed: 6.3ms preprocess, 194.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 201.9ms
# Speed: 6.1ms preprocess, 201.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 188.4ms
# Speed: 6.6ms preprocess, 188.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 183.4ms
# Speed: 6.5ms preprocess, 183.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 201.5ms
# Speed: 6.7ms preprocess, 201.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.6ms
# Speed: 5.4ms preprocess, 171.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.3ms
# Speed: 5.9ms preprocess, 168.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.5ms
# Speed: 7.1ms preprocess, 166.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.5ms
# Speed: 5.9ms preprocess, 172.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 174.5ms
# Speed: 6.2ms preprocess, 174.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 196.6ms
# Speed: 11.5ms preprocess, 196.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 198.3ms
# Speed: 7.3ms preprocess, 198.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 192.9ms
# Speed: 6.2ms preprocess, 192.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 197.7ms
# Speed: 6.1ms preprocess, 197.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 198.8ms
# Speed: 7.5ms preprocess, 198.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 176.0ms
# Speed: 3.7ms preprocess, 176.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.8ms
# Speed: 3.7ms preprocess, 167.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.5ms
# Speed: 5.6ms preprocess, 167.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.2ms
# Speed: 3.7ms preprocess, 171.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 176.5ms
# Speed: 5.9ms preprocess, 176.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 185.9ms
# Speed: 4.6ms preprocess, 185.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.5ms
# Speed: 5.7ms preprocess, 175.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.6ms
# Speed: 4.2ms preprocess, 169.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.5ms
# Speed: 4.4ms preprocess, 168.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.9ms
# Speed: 5.3ms preprocess, 175.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 185.2ms
# Speed: 5.3ms preprocess, 185.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.9ms
# Speed: 6.1ms preprocess, 169.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.9ms
# Speed: 7.3ms preprocess, 171.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 184.3ms
# Speed: 6.0ms preprocess, 184.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 265.9ms
# Speed: 6.7ms preprocess, 265.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 263.8ms
# Speed: 10.3ms preprocess, 263.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 260.4ms
# Speed: 3.8ms preprocess, 260.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 276.1ms
# Speed: 7.7ms preprocess, 276.1ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 279.7ms
# Speed: 11.3ms preprocess, 279.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 273.7ms
# Speed: 4.6ms preprocess, 273.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 297.3ms
# Speed: 7.6ms preprocess, 297.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 286.1ms
# Speed: 7.8ms preprocess, 286.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 260.5ms
# Speed: 6.9ms preprocess, 260.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 212.8ms
# Speed: 8.4ms preprocess, 212.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.2ms
# Speed: 6.2ms preprocess, 169.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 174.5ms
# Speed: 6.3ms preprocess, 174.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 180.2ms
# Speed: 6.0ms preprocess, 180.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.2ms
# Speed: 5.8ms preprocess, 168.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.7ms
# Speed: 6.1ms preprocess, 167.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.6ms
# Speed: 5.3ms preprocess, 164.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.3ms
# Speed: 6.5ms preprocess, 166.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 174.5ms
# Speed: 4.3ms preprocess, 174.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 180.8ms
# Speed: 6.5ms preprocess, 180.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.8ms
# Speed: 6.1ms preprocess, 163.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.4ms
# Speed: 4.6ms preprocess, 175.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 179.1ms
# Speed: 6.2ms preprocess, 179.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.8ms
# Speed: 5.8ms preprocess, 169.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 178.1ms
# Speed: 3.6ms preprocess, 178.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.9ms
# Speed: 5.7ms preprocess, 163.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.2ms
# Speed: 4.1ms preprocess, 166.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.8ms
# Speed: 5.7ms preprocess, 170.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 174.0ms
# Speed: 5.0ms preprocess, 174.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 203.1ms
# Speed: 4.7ms preprocess, 203.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.8ms
# Speed: 3.9ms preprocess, 165.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.0ms
# Speed: 4.9ms preprocess, 171.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.4ms
# Speed: 5.7ms preprocess, 168.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.3ms
# Speed: 6.1ms preprocess, 170.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 188.1ms
# Speed: 4.4ms preprocess, 188.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 203.9ms
# Speed: 7.4ms preprocess, 203.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 187.6ms
# Speed: 6.7ms preprocess, 187.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 187.5ms
# Speed: 7.2ms preprocess, 187.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 191.6ms
# Speed: 4.0ms preprocess, 191.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.2ms
# Speed: 3.6ms preprocess, 175.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 179.1ms
# Speed: 6.5ms preprocess, 179.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 180.4ms
# Speed: 4.4ms preprocess, 180.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 178.0ms
# Speed: 7.5ms preprocess, 178.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.6ms
# Speed: 4.3ms preprocess, 165.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 174.6ms
# Speed: 3.8ms preprocess, 174.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 183.9ms
# Speed: 5.8ms preprocess, 183.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.7ms
# Speed: 5.1ms preprocess, 172.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 202.9ms
# Speed: 2.9ms preprocess, 202.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 247.0ms
# Speed: 3.8ms preprocess, 247.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.0ms
# Speed: 6.1ms preprocess, 170.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.5ms
# Speed: 6.6ms preprocess, 170.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.0ms
# Speed: 6.7ms preprocess, 172.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 176.9ms
# Speed: 3.6ms preprocess, 176.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.3ms
# Speed: 5.7ms preprocess, 168.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.2ms
# Speed: 5.9ms preprocess, 170.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 180.6ms
# Speed: 3.4ms preprocess, 180.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.7ms
# Speed: 6.0ms preprocess, 172.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.1ms
# Speed: 8.6ms preprocess, 167.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 171.5ms
# Speed: 4.1ms preprocess, 171.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.5ms
# Speed: 4.0ms preprocess, 170.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 178.5ms
# Speed: 6.9ms preprocess, 178.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 269.9ms
# Speed: 5.9ms preprocess, 269.9ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 270.8ms
# Speed: 6.8ms preprocess, 270.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 284.8ms
# Speed: 6.6ms preprocess, 284.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 285.6ms
# Speed: 8.5ms preprocess, 285.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 279.7ms
# Speed: 11.5ms preprocess, 279.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 276.8ms
# Speed: 10.0ms preprocess, 276.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 298.6ms
# Speed: 7.7ms preprocess, 298.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 267.9ms
# Speed: 10.1ms preprocess, 267.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 270.6ms
# Speed: 8.4ms preprocess, 270.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 185.3ms
# Speed: 6.6ms preprocess, 185.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 179.5ms
# Speed: 5.9ms preprocess, 179.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.6ms
# Speed: 5.9ms preprocess, 170.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.9ms
# Speed: 5.7ms preprocess, 170.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.4ms
# Speed: 6.5ms preprocess, 170.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 196.8ms
# Speed: 7.3ms preprocess, 196.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 202.6ms
# Speed: 6.9ms preprocess, 202.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 194.2ms
# Speed: 7.0ms preprocess, 194.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 187.9ms
# Speed: 7.1ms preprocess, 187.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 195.3ms
# Speed: 8.5ms preprocess, 195.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 199.8ms
# Speed: 7.1ms preprocess, 199.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 199.7ms
# Speed: 7.3ms preprocess, 199.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 186.4ms
# Speed: 7.3ms preprocess, 186.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 197.5ms
# Speed: 7.6ms preprocess, 197.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 190.3ms
# Speed: 6.9ms preprocess, 190.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 191.4ms
# Speed: 7.3ms preprocess, 191.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 206.4ms
# Speed: 7.6ms preprocess, 206.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 194.2ms
# Speed: 4.1ms preprocess, 194.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 185.9ms
# Speed: 7.2ms preprocess, 185.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.7ms
# Speed: 4.2ms preprocess, 169.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.7ms
# Speed: 4.4ms preprocess, 175.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 180.6ms
# Speed: 3.7ms preprocess, 180.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 178.3ms
# Speed: 4.5ms preprocess, 178.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.4ms
# Speed: 3.9ms preprocess, 160.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.2ms
# Speed: 5.7ms preprocess, 168.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.5ms
# Speed: 5.7ms preprocess, 170.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 175.6ms
# Speed: 5.7ms preprocess, 175.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 168.9ms
# Speed: 5.4ms preprocess, 168.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 169.5ms
# Speed: 6.9ms preprocess, 169.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 169.2ms
# Speed: 6.9ms preprocess, 169.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 191.3ms
# Speed: 7.1ms preprocess, 191.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 207.6ms
# Speed: 6.1ms preprocess, 207.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 194.0ms
# Speed: 6.6ms preprocess, 194.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 190.0ms
# Speed: 7.2ms preprocess, 190.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 176.9ms
# Speed: 6.5ms preprocess, 176.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 166.3ms
# Speed: 4.2ms preprocess, 166.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 185.6ms
# Speed: 6.1ms preprocess, 185.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 173.0ms
# Speed: 6.2ms preprocess, 173.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 168.7ms
# Speed: 6.2ms preprocess, 168.7ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 175.1ms
# Speed: 6.5ms preprocess, 175.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 197.9ms
# Speed: 4.0ms preprocess, 197.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 204.5ms
# Speed: 6.5ms preprocess, 204.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 189.8ms
# Speed: 7.1ms preprocess, 189.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 186.4ms
# Speed: 5.4ms preprocess, 186.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 191.2ms
# Speed: 7.2ms preprocess, 191.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 181.7ms
# Speed: 8.0ms preprocess, 181.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 203.1ms
# Speed: 8.3ms preprocess, 203.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 187.3ms
# Speed: 7.5ms preprocess, 187.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 234.8ms
# Speed: 4.2ms preprocess, 234.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 277.7ms
# Speed: 6.6ms preprocess, 277.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 273.8ms
# Speed: 6.7ms preprocess, 273.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 259.0ms
# Speed: 10.5ms preprocess, 259.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 275.3ms
# Speed: 3.9ms preprocess, 275.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 628.9ms
# Speed: 7.3ms preprocess, 628.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 287.1ms
# Speed: 4.3ms preprocess, 287.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 301.0ms
# Speed: 10.1ms preprocess, 301.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Processing complete. Video saved as action_output.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'action_output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:09.93, start: 0.000000, bitrate: 3435 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 478x850 [SAR 1:1 DAR 239:425], 3433 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# File 'final_action_output.mp4' already exists. Overwrite? [y/N] y
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5ba06fdc2d40] using SAR=1/1
# [libx264 @ 0x5ba06fdc2d40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5ba06fdc2d40] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5ba06fdc2d40] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'final_action_output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 478x850 [SAR 1:1 DAR 239:425], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  298 fps= 19 q=-1.0 Lsize=    1422kB time=00:00:09.83 bitrate=1184.8kbits/s speed=0.617x
# video:1419kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.231387%
# [libx264 @ 0x5ba06fdc2d40] frame I:2     Avg QP:21.98  size: 20860
# [libx264 @ 0x5ba06fdc2d40] frame P:212   Avg QP:24.41  size:  5663
# [libx264 @ 0x5ba06fdc2d40] frame B:84    Avg QP:28.08  size:  2501
# [libx264 @ 0x5ba06fdc2d40] consecutive B-frames: 54.4% 20.1% 12.1% 13.4%
# [libx264 @ 0x5ba06fdc2d40] mb I  I16..4: 17.1% 75.6%  7.3%
# [libx264 @ 0x5ba06fdc2d40] mb P  I16..4:  2.5%  7.9%  0.6%  P16..4: 40.9% 11.5%  5.4%  0.0%  0.0%    skip:31.2%
# [libx264 @ 0x5ba06fdc2d40] mb B  I16..4:  1.3%  3.1%  0.2%  B16..8: 38.5%  5.1%  0.8%  direct: 1.6%  skip:49.5%  L0:52.0% L1:40.6% BI: 7.4%
# [libx264 @ 0x5ba06fdc2d40] 8x8 transform intra:71.6% inter:81.3%
# [libx264 @ 0x5ba06fdc2d40] direct mvs  spatial:97.6% temporal:2.4%
# [libx264 @ 0x5ba06fdc2d40] coded y,uvDC,uvAC intra: 50.4% 53.8% 5.1% inter: 13.8% 13.0% 2.3%
# [libx264 @ 0x5ba06fdc2d40] i16 v,h,dc,p: 49% 22% 18% 12%
# [libx264 @ 0x5ba06fdc2d40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 17% 33%  3%  2%  3%  2%  4%  3%
# [libx264 @ 0x5ba06fdc2d40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 50% 16%  9%  4%  4%  6%  4%  4%  3%
# [libx264 @ 0x5ba06fdc2d40] i8c dc,h,v,p: 36% 23% 34%  7%
# [libx264 @ 0x5ba06fdc2d40] Weighted P-Frames: Y:11.3% UV:1.4%
# [libx264 @ 0x5ba06fdc2d40] ref P L0: 65.7% 14.6% 12.1%  3.6%  2.3%  1.5%  0.2%
# [libx264 @ 0x5ba06fdc2d40] ref B L0: 84.3% 10.6%  4.3%  0.8%
# [libx264 @ 0x5ba06fdc2d40] ref B L1: 99.2%  0.8%
# [libx264 @ 0x5ba06fdc2d40] kb/s:1169.63

# %%
# Download the output video
files.download(compressed_video)
